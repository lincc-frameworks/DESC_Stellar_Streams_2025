# %% [markdown]
# Author: Sandro Campos, Neven Caplar and the LINCC Frameworks team
#
# Last updated: November 13, 2025

# %% [markdown]
# # Problem 4
#
# ## Find interesting objects from Rubin in ZTF
#
# Ok, we found these 10 interesting objects in Rubin data. Are they in any other dataset. How about data from Zwicky Transient Facility!
# LSDB has ave various ZTF datasets, e.g., https://data.lsdb.io/#ZTF/ZTF_DR22
# - How many of these objects are avaliable in ZTF?
# - Are you able to create folded lightcurve for those?

# %% [markdown]
# # Solution 4

# %%
import light_curve as licu
import lsdb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from io import StringIO
from dask.distributed import Client

# %% [markdown]
# ZTF DR23 is provided by IPAC via Amazon S3. To access such data we need to install `s3fs`. We will also install the `light_curve` package, which will later be used to estimate object periods based on their time-domain information.

# %%
# %pip install s3fs light_curve --quiet
# Out:
# WARNING: Error parsing dependencies of lsst-display-firefly: Invalid version: 'gca7fc764a6+19fcc35de2'
# WARNING: Error parsing dependencies of astshim: Invalid version: 'g2cef7863aa+73c82f25e4'
# WARNING: Error parsing dependencies of lsst-log: Invalid version: 'geaed405ab2+062dfc8cdc'
# WARNING: Error parsing dependencies of lsst-sphgeom: Invalid version: 'g00d0e8bbd7+edbf708997'
# WARNING: Error parsing dependencies of lsst-geom: Invalid version: 'g90f42f885a+6577634e1f'
# WARNING: Error parsing dependencies of lsst-pex-config: Invalid version: 'ga9e74d7ce9+128cc68277'
# WARNING: Error parsing dependencies of lsst-pex-exceptions: Invalid version: 'g786e29fd12+af89c03590'
# WARNING: Error parsing dependencies of lsst-base: Invalid version: 'g53246c7159+edbf708997'
# WARNING: Error parsing dependencies of lsst-cpputils: Invalid version: 'g87389fa792+a4172ec7da'
# WARNING: Error parsing dependencies of lsst-sconsutils: Invalid version: 'g50719a3ea6'
# WARNING: Error parsing dependencies of lsst-utils: Invalid version: 'ged10c03045+edbf708997'
# WARNING: Error parsing dependencies of lsst-daf-base: Invalid version: 'g8ea07a8fe4+79658f16ab'
# WARNING: Error parsing dependencies of lsst-afw: Invalid version: 'g9722cb1a7f+d8f85438e7'
# WARNING: Error parsing dependencies of lsst-dax-images-cutout: Invalid version: 'g64ef19dc7c+f006e20c11'
# WARNING: Error parsing dependencies of lsst-analysis-ap: Invalid version: 'g2ceca6568d+21ab085341'
# WARNING: Error parsing dependencies of lsst-display-astrowidgets: Invalid version: 'ge410e46f29+19fcc35de2'
# WARNING: Error parsing dependencies of lsst-drp-pipe: Invalid version: 'gf6e68d508d+42fbec640a'
# WARNING: Error parsing dependencies of lsst-atmospec: Invalid version: 'g34eda49c54+ac30ea53b7'
# WARNING: Error parsing dependencies of lsst-cp-verify: Invalid version: 'gf3e5369d4e+83af11c437'
# WARNING: Error parsing dependencies of lsst-faro: Invalid version: 'gaff3cf7e18+6632da9768'
# WARNING: Error parsing dependencies of lsst-sdm-tools: Invalid version: 'gd0a0adbdb3+5f9b7a7fed'
# WARNING: Error parsing dependencies of lsst-display-matplotlib: Invalid version: 'g67b6fd64d1+19fcc35de2'
# WARNING: Error parsing dependencies of lsst-ap-verify: Invalid version: 'g52e624231e+5748eef6dd'
# WARNING: Error parsing dependencies of lsst-jointcal: Invalid version: 'g29ae962dfc+34be89a2fc'
# WARNING: Error parsing dependencies of lsst-cbp: Invalid version: 'gdf01333386+19fcc35de2'
# WARNING: Error parsing dependencies of lsst-obs-fiberspectrograph: Invalid version: 'g49223bffc5+a58ce20db5'
# WARNING: Error parsing dependencies of lsst-obs-rubingenericcamera: Invalid version: 'gedca799cae+a58ce20db5'
# WARNING: Error parsing dependencies of lsst-obs-cfht: Invalid version: 'g8219804093+a24ac419f1'
# WARNING: Error parsing dependencies of lsst-multiprofit: Invalid version: 'gc0c0f8bcd6+29c7ac1691'
# WARNING: Error parsing dependencies of lsst-meas-extensions-multiprofit: Invalid version: 'gd7f5286ac6+7fd2defc4e'
# WARNING: Error parsing dependencies of lsst-rucio-register: Invalid version: 'g9122ee4c28+bdeae04681'
# WARNING: Error parsing dependencies of lsst-ctrl-bps-parsl: Invalid version: 'gb6dcdd3a21+e636154823'
# WARNING: Error parsing dependencies of lsst-ctrl-bps-panda: Invalid version: 'g6627e23f00+e636154823'
# WARNING: Error parsing dependencies of lsst-lsst-bps-plugins: Invalid version: 'g7de033f5be+8a25b2a96f'
# WARNING: Error parsing dependencies of lsst-ctrl-platform-s3df: Invalid version: 'g0ef25d5091+c84af64bb8'
# WARNING: Error parsing dependencies of lsst-ctrl-mpexec: Invalid version: 'g24947d5ec1+bd62891fed'
# WARNING: Error parsing dependencies of lsst-ctrl-bps: Invalid version: 'g72ff1dd783+54e8d035b1'
# WARNING: Error parsing dependencies of lsst-ctrl-bps-htcondor: Invalid version: 'gaccf33cbef+e636154823'
# WARNING: Error parsing dependencies of lsst-ctrl-execute: Invalid version: 'g112f17a8a8+2c9502ff54'
# WARNING: Error parsing dependencies of lsst-display-ds9: Invalid version: 'gd7ef33dd92+19fcc35de2'
# WARNING: Error parsing dependencies of lsst-meas-extensions-simpleshape: Invalid version: 'gdab6d2f7ff+6e038728f1'
# WARNING: Error parsing dependencies of lsst-meas-transinet: Invalid version: 'gd42b450c19+6e038728f1'
# WARNING: Error parsing dependencies of lsst-source-injection: Invalid version: 'ga2d503612c+83af11c437'
# WARNING: Error parsing dependencies of lsst-cell-coadds: Invalid version: 'gd5450080d9+4b0bbba5ce'
# WARNING: Error parsing dependencies of lsst-drp-tasks: Invalid version: 'g5bf09c0d5d+54dcb669f0'
# WARNING: Error parsing dependencies of lsst-fgcmcal: Invalid version: 'g98df359435+0f66fdfca5'
# WARNING: Error parsing dependencies of lsst-obs-lsst: Invalid version: 'g1217d0f59f+8032c468dc'
# WARNING: Error parsing dependencies of lsst-obs-decam: Invalid version: 'g8d7436a09f+1c65fffe91'
# WARNING: Error parsing dependencies of lsst-obs-subaru: Invalid version: 'ga94e9f2cd1+b8084c06ed'
# WARNING: Error parsing dependencies of lsst-cp-pipe: Invalid version: 'g766e4ace53+740cadb8b6'
# WARNING: Error parsing dependencies of lsst-analysis-tools: Invalid version: 'gc4380ab8aa+60061da568'
# WARNING: Error parsing dependencies of lsst-ap-association: Invalid version: 'g921ca29d17+7a370a384b'
# WARNING: Error parsing dependencies of lsst-ap-pipe: Invalid version: 'g6dd8f547b4+f5dbdc29cd'
# WARNING: Error parsing dependencies of lsst-scarlet-lite: Invalid version: 'ga2180abaac+edbf708997'
# WARNING: Error parsing dependencies of lsst-meas-extensions-scarlet: Invalid version: 'gfd6555b056+3e4396594a'
# WARNING: Error parsing dependencies of lsst-meas-extensions-psfex: Invalid version: 'g3fd5ace14f+0f9585b40d'
# WARNING: Error parsing dependencies of lsst-meas-extensions-piff: Invalid version: 'ge41e95a9f2+33d965bf6c'
# WARNING: Error parsing dependencies of lsst-meas-extensions-gaap: Invalid version: 'g5c7ea12361+e7ad0acc57'
# WARNING: Error parsing dependencies of lsst-meas-extensions-photometrykron: Invalid version: 'g64539dfbff+33d965bf6c'
# WARNING: Error parsing dependencies of lsst-meas-extensions-convolved: Invalid version: 'g7da95dfc27+5e6e44f9b1'
# WARNING: Error parsing dependencies of lsst-ip-isr: Invalid version: 'gc2a301910b+33d965bf6c'
# WARNING: Error parsing dependencies of lsst-verify-metrics: Invalid version: 'g8b480f84d9+edbf708997'
# WARNING: Error parsing dependencies of lsst-sdm-schemas: Invalid version: 'g3eb46086f9+edbf708997'
# WARNING: Error parsing dependencies of lsst-felis: Invalid version: 'g5c320bd705+4529a0555a'
# WARNING: Error parsing dependencies of lsst-dax-apdb: Invalid version: 'g88cb488625+cdc2ed4845'
# WARNING: Error parsing dependencies of lsst-verify: Invalid version: 'g00d583acbd+84fd9c2286'
# WARNING: Error parsing dependencies of lsst-meas-extensions-shapehsm: Invalid version: 'gf8a46c3309+33d965bf6c'
# WARNING: Error parsing dependencies of lsst-meas-extensions-trailedsources: Invalid version: 'g74acd417e5+6e038728f1'
# WARNING: Error parsing dependencies of lsst-meas-astrom: Invalid version: 'gdbb4c4dda9+33d965bf6c'
# WARNING: Error parsing dependencies of lsst-ip-diffim: Invalid version: 'g5b326b94bb+74795fc0b3'
# WARNING: Error parsing dependencies of lsst-coadd-utils: Invalid version: 'g89139ef638+19fcc35de2'
# WARNING: Error parsing dependencies of lsst-pipe-tasks: Invalid version: 'ge8e7e3f09d+a09b026073'
# WARNING: Error parsing dependencies of lsst-shapelet: Invalid version: 'g47891489e3+19fcc35de2'
# WARNING: Error parsing dependencies of lsst-meas-modelfit: Invalid version: 'g7aefaa3e3d+a53f4933b3'
# WARNING: Error parsing dependencies of astro-metadata-translator: Invalid version: 'gf746e4f9fc+02a42095d5'
# WARNING: Error parsing dependencies of lsst-obs-base: Invalid version: 'g1a55b07155+45857cba52'
# WARNING: Error parsing dependencies of lsst-pipe-base: Invalid version: 'gaa98aacebd+4a15ede1ff'
# WARNING: Error parsing dependencies of lsst-resources: Invalid version: 'gac860778b9+062dfc8cdc'
# WARNING: Error parsing dependencies of lsst-daf-butler: Invalid version: 'g510790da9a+ea63be4a5d'
# WARNING: Error parsing dependencies of lsst-skymap: Invalid version: 'g1fd858c14a+5d3c95268f'
# WARNING: Error parsing dependencies of lsst-meas-base: Invalid version: 'g5e032395f3+2a361f5c28'
# WARNING: Error parsing dependencies of lsst-meas-algorithms: Invalid version: 'g3541666cd7+00c381f533'
# WARNING: Error parsing dependencies of lsst-meas-deblender: Invalid version: 'g262e1987ae+129725fbd9'
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load ZTF with LSDB
ztf_dr23 = lsdb.open_catalog("s3://ipac-irsa-ztf/contributed/dr23/lc/hats")

# %%
# Crossmatch with 10 variable locations
variables_csv = """ra,dec,period
94.95546,-24.73952,0.12095
95.30235,-25.27431,0.12248
94.91626,-24.69648,0.12038
95.12418,-25.04329,0.23554
58.83506,-48.79122,0.56335
94.92264,-25.23185,0.07672
94.72086,-25.05767,0.17559
94.97073,-25.13643,0.12048
59.12997,-48.78522,0.11628
94.72086,-25.05767,0.17554
"""
variables_df = pd.read_csv(StringIO(variables_csv)).reset_index()

# %% [markdown]
# In ZTF a single astronomical object will be identified by multiple object IDs (due to the fact that objects found in different detectors are treated separately). To make sure we are not missing any relevant detections for each object, we will perform the crossmatch with a large radius (1 arcsec) and a large number of neighbors (20).

# %%
result = lsdb.crossmatch(
    variables_df,
    ztf_dr23,
    radius_arcsec=1,
    n_neighbors=20,
    suffixes=["_var", "_ztf_dr23"],
)
# Out:
# /opt/lsst/software/stack/conda/envs/lsst-scipipe-12.0.0/lib/python3.13/site-packages/lsdb/catalog/catalog.py:256: FutureWarning: The default suffix behavior will change from applying suffixes to all columns to only applying suffixes to overlapping columns in a future release.To maintain the current behavior, explicitly set `suffix_method='all_columns'`. To change to the new behavior, set `suffix_method='overlapping_columns'`.
#   warnings.warn(

# %% [markdown]
# We should also filter by "catflags" to remove invalid detections:

# %%
# Filter out the invalid ones
result = result.query("lightcurve_ztf_dr23.catflags == 0")
result
# Out:
# Dask NestedFrame Structure:
#                           index_var           ra_var          dec_var       period_var objectid_ztf_dr23 filterid_ztf_dr23  objra_ztf_dr23 objdec_ztf_dr23                                                                          lightcurve_ztf_dr23     _dist_arcsec
# npartitions=2
# 1445655480385929216  int64[pyarrow]  double[pyarrow]  double[pyarrow]  double[pyarrow]    int64[pyarrow]     int8[pyarrow]  float[pyarrow]  float[pyarrow]  nested<hmjd: [double], mag: [float], magerr: [float], clrcoeff: [float], catflags: [int32]>  double[pyarrow]
# 1455788579547512832             ...              ...              ...              ...               ...               ...             ...             ...                                                                                          ...              ...
# 1456914479454355456             ...              ...              ...              ...               ...               ...             ...             ...                                                                                          ...              ...
# Dask Name: lambda, 4 expressions
# Expr=MapPartitions(lambda)

# %% [markdown]
# The following computation takes about ~1min to run on 2 workers:

# %%
with Client(n_workers=2, threads_per_worker=1, dashboard_address=":38765") as client:
    result_df = result.compute().sort_values("index_var")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: State start</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>:   Scheduler at:     tcp://127.0.0.1:42155</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>:   dashboard at:  https://nevencaplar.nb.data.lsst.cloud/nb/user/nevencaplar/proxy/38765/status</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Registering Worker plugin shuffle</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>:         Start Nanny at: &#x27;tcp://127.0.0.1:42221&#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>:         Start Nanny at: &#x27;tcp://127.0.0.1:32827&#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Register worker addr: tcp://127.0.0.1:44591 name: 0</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Starting worker compute stream, tcp://127.0.0.1:44591</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Starting established connection to tcp://127.0.0.1:35082</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Register worker addr: tcp://127.0.0.1:36101 name: 1</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Starting worker compute stream, tcp://127.0.0.1:36101</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Starting established connection to tcp://127.0.0.1:35090</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Receive client connection: Client-59052027-c0be-11f0-a588-7b08caef82ff</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Starting established connection to tcp://127.0.0.1:35094</pre>
# 2025-11-13 18:28:00,119 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.60 GiB -- Worker memory limit: 8.00 GiB
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny.memory</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Worker tcp://127.0.0.1:36101 (pid=10305) exceeded 95% memory budget. Restarting...</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Connection to tcp://127.0.0.1:35090 has been closed.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Remove worker addr: tcp://127.0.0.1:36101 name: 1 (stimulus_id=&#x27;handle-worker-cleanup-1763058486.296219&#x27;)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Removing worker &#x27;tcp://127.0.0.1:36101&#x27; caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {(&#x27;nestedframe-a92fbb441992984518eaa43873d4f14b&#x27;, 0), (&#x27;read_pixel-_to_string_dtype-nestedframe-7cba8aad1f6f9b56b437794383a872ca&#x27;, 6124), (&#x27;read_pixel-_to_string_dtype-nestedframe-08b1e1d7b57b1e6fa01434e82d6aaec3&#x27;, 6124)} (stimulus_id=&#x27;handle-worker-cleanup-1763058486.296219&#x27;)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>: Worker process 10305 was killed by signal 15</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Restarting worker</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Register worker addr: tcp://127.0.0.1:46063 name: 1</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Starting worker compute stream, tcp://127.0.0.1:46063</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Starting established connection to tcp://127.0.0.1:34314</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny.memory</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Worker tcp://127.0.0.1:46063 (pid=10375) exceeded 95% memory budget. Restarting...</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Connection to tcp://127.0.0.1:34314 has been closed.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Remove worker addr: tcp://127.0.0.1:46063 name: 1 (stimulus_id=&#x27;handle-worker-cleanup-1763058532.6033828&#x27;)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Removing worker &#x27;tcp://127.0.0.1:46063&#x27; caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {(&#x27;nestedframe-a92fbb441992984518eaa43873d4f14b&#x27;, 0), (&#x27;read_pixel-_to_string_dtype-nestedframe-7cba8aad1f6f9b56b437794383a872ca&#x27;, 6124), (&#x27;read_pixel-_to_string_dtype-nestedframe-08b1e1d7b57b1e6fa01434e82d6aaec3&#x27;, 6124)} (stimulus_id=&#x27;handle-worker-cleanup-1763058532.6033828&#x27;)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>: Worker process 10375 was killed by signal 15</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Restarting worker</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Register worker addr: tcp://127.0.0.1:34859 name: 1</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Starting worker compute stream, tcp://127.0.0.1:34859</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Starting established connection to tcp://127.0.0.1:57922</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Remove client Client-59052027-c0be-11f0-a588-7b08caef82ff</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Received &#x27;close-stream&#x27; from tcp://127.0.0.1:35094; closing.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Remove client Client-59052027-c0be-11f0-a588-7b08caef82ff</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Close client connection: Client-59052027-c0be-11f0-a588-7b08caef82ff</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Retire worker addresses (stimulus_id=&#x27;retire-workers-1763058572.999517&#x27;) (0, 1)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>: Closing Nanny at &#x27;tcp://127.0.0.1:42221&#x27;. Reason: nanny-close</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>: Nanny asking worker to close. Reason: nanny-close</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>: Closing Nanny at &#x27;tcp://127.0.0.1:32827&#x27;. Reason: nanny-close</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>: Nanny asking worker to close. Reason: nanny-close</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Received &#x27;close-stream&#x27; from tcp://127.0.0.1:35082; closing.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Remove worker addr: tcp://127.0.0.1:44591 name: 0 (stimulus_id=&#x27;handle-worker-cleanup-1763058573.0063446&#x27;)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.core</span> <span style="color: var(--jp-info-color0)">INFO</span>: Received &#x27;close-stream&#x27; from tcp://127.0.0.1:57922; closing.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Remove worker addr: tcp://127.0.0.1:34859 name: 1 (stimulus_id=&#x27;handle-worker-cleanup-1763058573.0093327&#x27;)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Lost all workers</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>: Nanny at &#x27;tcp://127.0.0.1:42221&#x27; closed.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.nanny</span> <span style="color: var(--jp-info-color0)">INFO</span>: Nanny at &#x27;tcp://127.0.0.1:32827&#x27; closed.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Closing scheduler. Reason: unknown</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">distributed.scheduler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Scheduler closing all comms</pre>

# %% [markdown]
# There are matches for 8 out of the 10 variable objects we specified (in fact, 2 for each).

# %%
result_df
# Out:
#                      index_var    ra_var   dec_var  period_var  \
# _healpix_29
# 1456157018405184225          0  94.95546 -24.73952     0.12095
# 1456157018405184225          0  94.95546 -24.73952     0.12095
# 1450131236226156835          1  95.30235 -25.27431     0.12248
# 1450131236226156835          1  95.30235 -25.27431     0.12248
# 1456157750233453047          2  94.91626 -24.69648     0.12038
# 1456157750233453047          2  94.91626 -24.69648     0.12038
# 1456145241786549427          3  95.12418 -25.04329     0.23554
# 1456145241786549427          3  95.12418 -25.04329     0.23554
# 1456140633585049253          5  94.92264 -25.23185     0.07672
# 1456140633585049253          5  94.92264 -25.23185     0.07672
# 1456149791804243835          6  94.72086 -25.05767     0.17559
# 1456149791804243835          6  94.72086 -25.05767     0.17559
# 1456142101772261065          7  94.97073 -25.13643     0.12048
# 1456142101772261065          7  94.97073 -25.13643     0.12048
# 1456149791804243835          9  94.72086 -25.05767     0.17554
# 1456149791804243835          9  94.72086 -25.05767     0.17554
#
#                      objectid_ztf_dr23  filterid_ztf_dr23  objra_ztf_dr23  \
# _healpix_29
# 1456157018405184225    258208100006442                  2       94.955467
# 1456157018405184225    258108100009037                  1       94.955482
# 1450131236226156835    258207300001033                  2       95.302368
# 1450131236226156835    258107300000583                  1        95.30233
# 1456157750233453047    258208100005846                  2        94.91626
# 1456157750233453047    258108100003289                  1        94.91626
# 1456145241786549427    258208100010900                  2       95.124191
# 1456145241786549427    258108100006202                  1       95.124191
# 1456140633585049253    258108400000373                  1       94.922646
# 1456140633585049253    258208400035461                  2       94.922623
# 1456149791804243835    258108100006348                  1       94.720856
# 1456149791804243835    258208100011136                  2       94.720848
# 1456142101772261065    258208100024003                  2       94.970718
# 1456142101772261065    258108100007040                  1       94.970779
# 1456149791804243835    258108100006348                  1       94.720856
# 1456149791804243835    258208100011136                  2       94.720848
#
#                      objdec_ztf_dr23  \
# _healpix_29
# 1456157018405184225       -24.739527
# 1456157018405184225       -24.739544
# 1450131236226156835        -25.27429
# 1450131236226156835       -25.274321
# 1456157750233453047       -24.696495
# 1456157750233453047       -24.696501
# 1456145241786549427       -25.043276
# 1456145241786549427       -25.043272
# 1456140633585049253       -25.231831
# 1456140633585049253       -25.231833
# 1456149791804243835       -25.057667
# 1456149791804243835       -25.057661
# 1456142101772261065       -25.136433
# 1456142101772261065       -25.136465
# 1456149791804243835       -25.057667
# 1456149791804243835       -25.057661
#
#                                                    lightcurve_ztf_dr23  \
# _healpix_29
# 1456157018405184225  [{hmjd: 58397.52198, mag: 18.0459, magerr: 0.0...
# 1456157018405184225  [{hmjd: 58423.44057, mag: 19.25569, magerr: 0....
# 1450131236226156835  [{hmjd: 58397.52194, mag: 18.846132, magerr: 0...
# 1450131236226156835  [{hmjd: 58426.44323, mag: 19.634962, magerr: 0...
# 1456157750233453047  [{hmjd: 58397.52198, mag: 17.228245, magerr: 0...
# 1456157750233453047  [{hmjd: 58423.44057, mag: 17.41291, magerr: 0....
# 1456145241786549427  [{hmjd: 58397.52196, mag: 15.731258, magerr: 0...
# 1456145241786549427  [{hmjd: 58423.44054, mag: 15.66658, magerr: 0....
# 1456140633585049253  [{hmjd: 58423.44055, mag: 18.452045, magerr: 0...
# 1456140633585049253  [{hmjd: 58397.52198, mag: 18.646429, magerr: 0...
# 1456149791804243835  [{hmjd: 58423.44057, mag: 18.003967, magerr: 0...
# 1456149791804243835  [{hmjd: 58397.522, mag: 17.645302, magerr: 0.0...
# 1456142101772261065  [{hmjd: 58397.52197, mag: 19.351124, magerr: 0...
# 1456142101772261065  [{hmjd: 58423.44055, mag: 19.816902, magerr: 0...
# 1456149791804243835  [{hmjd: 58423.44057, mag: 18.003967, magerr: 0...
# 1456149791804243835  [{hmjd: 58397.522, mag: 17.645302, magerr: 0.0...
#
#                      _dist_arcsec
# _healpix_29
# 1456157018405184225      0.034677
# 1456157018405184225      0.112217
# 1450131236226156835       0.08676
# 1450131236226156835       0.09001
# 1456157750233453047      0.055427
# 1456157750233453047      0.070902
# 1456145241786549427      0.060675
# 1456145241786549427      0.070503
# 1456140633585049253      0.071208
# 1456140633585049253      0.084363
# 1456149791804243835      0.029192
# 1456149791804243835      0.056406
# 1456142101772261065      0.031329
# 1456142101772261065      0.211717
# 1456149791804243835      0.029192
# 1456149791804243835      0.056406

# %% [markdown]
# Each object match has light curve data in one band - either "g" (`filterid_ztf_dr23` == 1) or "r" (`filterid_ztf_dr23` == 2).

# %%
# Mapping of filter IDs to band names
FILTER_ID_TO_BAND = {1: "g", 2: "r", 3: "i"}

# Mapping of band names to colors for plotting
COLORS = {"g": "green", "r": "red", "i": "purple"}


def estimate_period(approx_period, hmjds, mags):
    """Find the period for a certain lightcurve based on an estimate"""
    freqs = (
        2.0 * np.pi * np.linspace(0.999 / approx_period, 1.001 / approx_period, 10_000)
    )
    t = np.asarray(hmjds, dtype=np.float32)
    mags = np.asarray(mags, dtype=np.float32)
    _, sort_index = np.unique(t, return_index=True)
    return licu.Periodogram(fast=False, freqs=freqs)(t[sort_index], mags[sort_index])[0]

# %%
def plot_lightcurves(ax, group):
    """Plot lightcurves for the matches of a variable object"""
    all_lcs = []
    for _, row in group.iterrows():
        lc = row.lightcurve_ztf_dr23
        period = estimate_period(row.period_var, lc.hmjd, lc.mag)
        # Compute phase
        lc = lc.assign(phase=(lc.hmjd - lc.hmjd.loc[lc.mag.idxmax()]) % period / period)
        band = FILTER_ID_TO_BAND[row.filterid_ztf_dr23]
        label = f"{band}, ZTF_ID={row.objectid_ztf_dr23}, period={period:.7f}"
        # Plot each row's lightcurve (label only for phase plot to avoid duplicates)
        plot_mag_scale(
            ax[0], lc, "mag", "magerr", band, None, x_name="hmjd", x_label="HMJD"
        )
        plot_mag_scale(
            ax[1], lc, "mag", "magerr", band, label, x_name="phase", x_label="Phase"
        )
    # Add legend to the figure
    fig.legend(loc="upper center", bbox_to_anchor=(0.5, -0.02), ncol=3, fontsize=12)


def plot_mag_scale(ax, lc, mag_col, magerr_col, band, legend, x_name, x_label):
    """Plot lightcurve in magnitude scale"""
    mag = lc[mag_col]
    magErr = lc[magerr_col]
    ax.errorbar(
        lc[x_name],
        mag,
        magErr,
        fmt="o",
        label=legend,
        color=COLORS[band],
        alpha=1,
        markersize=5,
        capsize=3,
        elinewidth=1,
    )
    if x_label == "Phase":
        ax.set_xlim([0, 1])  # Fix the axis limits
    ax.set_xlabel(x_label)
    ax.set_ylabel("Magnitude")

# %% [markdown]
# Finally, let's plot them. Each figure that follows has:
# - On the left, the original light curves for the two matches.
# - On the right, the corresponding folded light curves.
# - On the bottom, a legend specifying the objects they correspond to and their estimated period.

# %%
for index_var, group in result_df.groupby("index_var"):
    fig, ax = plt.subplots(1, 2, figsize=(16, 5), constrained_layout=True)
    period = plot_lightcurves(ax, group)
    row = group.iloc[0]
    # Magnitudes are plotted with brighter objects lower
    ax[0].invert_yaxis()
    ax[1].invert_yaxis()
    # Set figure titles
    title = f"Variable object {row.index_var}"
    title += f"\nRA={row.ra_var}, DEC={row.dec_var}"
    fig.suptitle(title, fontsize=16)
    plt.show()
